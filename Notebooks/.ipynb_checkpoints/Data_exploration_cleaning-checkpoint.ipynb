# %%
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %%
# %cd /Users/abigailhotaling/Documents/STAT 330 Project
filename = 'Electricity_Residential_Price_New_England.csv'
data = pd.read_csv(filename)
# Out:
# /Users/abigailhotaling/Documents/STAT 330 Project

# %%
data.columns = ['Month','Price']

# %%
plt.plot(data['Price'])

# %%
months = list(dat['Month'])
years = list(range(1997,2020))
prices = list(dat['Electricity Residential Price: New England cents per kilowatthour'])

for i in range(len(dat['Month'])):
    dat['Month and Year'] = dat['Month'][i].replace('-', ' ')
    dat['Months'] = dat['Month'][i][0:-2].replace('-', ' ')
    dat['Year'] = dat['Month'][i][-2:]

# %%
#test = pd.to_datetime(data['Month'])
datetime.strptime(data['Month'][0], '%m-%y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-33-4abb58abbdb7> in <module>()
#       1 #test = pd.to_datetime(data['Month'])
# ----> 2 datetime.strptime(data['Month'][0], '%m-%y')
#
# ~/anaconda3/lib/python3.6/_strptime.py in _strptime_datetime(cls, data_string, format)
#     563     """Return a class cls instance based on the input string and the
#     564     format string."""
# --> 565     tt, fraction = _strptime(data_string, format)
#     566     tzname, gmtoff = tt[-2:]
#     567     args = tt[:6] + (fraction,)
#
# ~/anaconda3/lib/python3.6/_strptime.py in _strptime(data_string, format)
#     360     if not found:
#     361         raise ValueError("time data %r does not match format %r" %
# --> 362                          (data_string, format))
#     363     if len(data_string) != found.end():
# ...

# %%
data['Month'][0]
# Out:
# 'Dec-19'

# %%
data['Price']
# Out:
# 0      20.86
# 1      21.16
# 2      21.28
# 3      21.30
# 4      20.75
# 5      21.21
# 6      21.20
# 7      21.68
# 8      21.82
# 9      21.45
# 10     21.66
# 11     20.80
# 12     19.93
# 13     20.21
# 14     20.22
# 15     19.79
# 16     19.21
# 17     19.93
# 18     20.36
# 19     20.63
# 20     20.79
# 21     20.70
# 22     20.94
# 23     19.82
# 24     18.97
# 25     19.44
# 26     19.53
# 27     19.29
# 28     18.88
# 29     18.79
#        ...
# 247    11.38
# 248    11.43
# 249    11.15
# 250    11.33
# 251    10.95
# 252    11.52
# 253    11.39
# 254    11.44
# 255    11.24
# 256    11.67
# 257    11.55
# 258    11.74
# 259    11.70
# 260    11.59
# 261    11.63
# 262    11.67
# 263    11.60
# 264    12.26
# 265    11.99
# 266    12.34
# 267    12.05
# 268    12.25
# 269    12.10
# 270    12.65
# 271    12.03
# 272    11.54
# 273    12.07
# 274    11.73
# 275    11.81
# 276    12.30
# Name: Price, Length: 277, dtype: float64
